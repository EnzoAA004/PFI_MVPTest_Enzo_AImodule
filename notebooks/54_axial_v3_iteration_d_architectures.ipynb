# %% [markdown]
# # Axial v3 Iteration D - architecture comparison
#
# Scaffolding seguro. No habilita arquitecturas no implementadas.

# %%
from lumbar_mri.axial_v3.architectures import ArchitectureConfig, build_axial_v3_model, planned_architecture_metadata
from lumbar_mri.axial_v3.guards import require_train_val_only

ALLOWED_SPLITS = require_train_val_only(["train", "val"], context="notebook_54")

# %%
ARCHITECTURE_PLAN = planned_architecture_metadata()


def build_reference_model():
    return build_axial_v3_model(ArchitectureConfig(name="axial_unet2d", in_channels=1))

# %% [markdown]
# ## Scope rule
#
# Iteration D runs only if B and C do not provide sufficient validation evidence and extra deployment complexity is justified.
